# %% [markdown]
# # **Project Name**    -HOTEL BOOKING ANALYSIS

# %% [markdown]
# # **Project Summary -**
# We can analyze the timing of guest arrivals, including the year, month, week number, and day of the month. This temporal data is vital for identifying peak periods when hotels experience higher occupancy rates. By examining whether guests are more likely to book stays during weekends or weekdays, hotels can better manage staffing and resources to accommodate busy times.
#
# The dataset also contains valuable insights about the guests themselves, such as their country of origin, the method of booking (online or through an agent), and whether they have booked before. This information helps hotels gain a deeper understanding of their clientele and tailor services to enhance guest satisfaction.
#
# Furthermore, we can examine details related to room reservations, including the type of room booked versus the type actually assigned to guests. This allows hotels to assess booking accuracy and manage room allocations effectively, ensuring guests receive their preferred accommodations. The dataset also highlights any changes made to bookings and the payment methods used, providing insights into customer preferences.
#
# Financial metrics within the dataset reveal important information, such as costs associated with bookings through different channels and the overall revenue generated from reservations. Analyzing these figures helps hotels understand their financial performance and assess the effectiveness of promotional strategies. Additionally, the dataset captures special requests made by guests, shedding light on what amenities or services guests value most.
#
# Lastly, the dataset allows us to evaluate the ratio of guests who checked in versus those who canceled their bookings. This information is crucial for hotels to enhance their demand forecasting, ensuring they are adequately prepared for peak periods and have sufficient staffing to meet guest needs.
#
# Overall, this dataset offers a comprehensive view of hotel bookings, guest demographics, and operational metrics. The insights gained from this analysis can significantly assist hotels in improving service delivery, optimizing operational efficiency, and enhancing guest experiences. By leveraging this information, hotels can implement strategies that align with customer preferences, ultimately driving satisfaction and loyalty in a competitive hospitality market.

# %% [markdown]
# # Problem Statement
# **Problem 1 :** Hotels often struggle to predict peak booking periods, leading to inefficient resource allocation and staffing. Without clear insights into seasonal trends and booking behaviors, hotels may miss opportunities for maximizing occupancy and revenue.
#
# **Solution 1:** By analyzing the dataset to visualize booking trends over time, we identified peak seasons and periods of high demand. This insight allows hotel management to optimize staffing and resource allocation during busy times. Guest Demographics and Preferences:
#
#
# **Problem 2:** Hotels need to understand their guests better to tailor services and improve customer satisfaction. Without knowledge of guest demographics and booking preferences, hotels risk offering generic services that may not meet individual needs.
#
# **Solution 2:** The analysis provided insights into guest demographics, including origins and booking methods. By examining this data, hotels can tailor their marketing strategies and enhance personalized services based on guest preferences. Cancellation Impact on Revenue:
#
#
# **Problem 3 :** High cancellation rates can significantly impact hotel revenue and planning. Hotels require a better understanding of cancellation patterns to improve booking policies and minimize financial losses.
#
# **Solution 3:** By examining the cancellation rates in relation to actual check-ins, we were able to assess the impact of cancellations on overall revenue. This analysis helps hotels refine their booking policies and implement strategies to reduce cancellation rates. Room Allocation Efficiency:

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# # *1. Know Your Data*

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset Loading

# %%
from google.colab import files

# Upload the CSV file from your local machine
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6fd0e41-8246-4950-b1a7-9d84fc6b2e2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6fd0e41-8246-4950-b1a7-9d84fc6b2e2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
hotel_df = pd.read_csv('Hotel Bookings.csv')  # Use the exact name of the uploaded file

# Display the first few rows of the dataset
print(hotel_df.head())
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Display information about the dataset
print(hotel_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # Dataset First View

# %%
# Dataset First Look
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# # Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print("Dataset Rows & Columns Count: ", hotel_df.shape)
# Out:
# Dataset Rows & Columns Count:  (119390, 32)

# %% [markdown]
# # Dataset Information

# %%
# Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # Duplicate Values

# %%
# Dataset Duplicate Value Count
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Missing Values/Null Values

# %%
# Unique distinct Values Count
for column in hotel_df.columns:
    print(f"Unique values in '{column}': {hotel_df[column].nunique()}")
# Out:
# Unique values in 'hotel': 2
# Unique values in 'is_canceled': 2
# Unique values in 'lead_time': 479
# Unique values in 'arrival_date_year': 3
# Unique values in 'arrival_date_month': 12
# Unique values in 'arrival_date_week_number': 53
# Unique values in 'arrival_date_day_of_month': 31
# Unique values in 'stays_in_weekend_nights': 17
# Unique values in 'stays_in_week_nights': 35
# Unique values in 'adults': 14
# Unique values in 'children': 5
# Unique values in 'babies': 5
# Unique values in 'meal': 5
# Unique values in 'country': 177
# Unique values in 'market_segment': 8
# Unique values in 'distribution_channel': 5
# Unique values in 'is_repeated_guest': 2
# Unique values in 'previous_cancellations': 15
# Unique values in 'previous_bookings_not_canceled': 73
# Unique values in 'reserved_room_type': 10
# Unique values in 'assigned_room_type': 12
# Unique values in 'booking_changes': 21
# Unique values in 'deposit_type': 3
# Unique values in 'agent': 333
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(12, 8))
sns.heatmap(hotel_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# Count missing values per column
missing_values = hotel_df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# ...

# %% [markdown]
# # ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(hotel_df.columns)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Variables Description
#
# **hotel:** Type of hotel (City Hotel or Resort Hotel).
#
# **is_canceled:** Whether the booking was canceled (1) or not (0).
#
# **lead_time:** Number of days between booking and arrival.
#
# **arrival_date_year:** Year of arrival date.
#
# **arrival_date_month:** Month of arrival date.
#
# **arrival_date_week_number:** Week number of the year for arrival date.
#
# **arrival_date_day_of_month:** Day of the month for arrival.
#
# **stays_in_weekend_nights:** Number of weekend nights (Saturday/Sunday) the guest stayed.
#
# **stays_in_week_nights:** Number of weeknights (Monday to Friday) the guest stayed.
#
# **adults:** Number of adults.
#
# **children:** Number of children.
#
# **babies:** Number of babies.
#
# **meal:** Type of meal booked (BB: Bed & Breakfast, HB: Half Board, FB: Full Board, etc.).
#
# **country:** Country of origin of the guest.
#
#
# **market_segment:** Market segment designation (e.g., online booking, direct booking).
#
# **distribution_channel**: The channel through which the booking was made (e.g., corporate, travel agent).
#
# **is_repeated_guest**: Whether the guest is a returning guest (1) or not (0).
#
# **previous_cancellations**: Number of previous bookings that were canceled by the customer.
#
# **previous_bookings_not_canceled:** Number of previous bookings not canceled by the customer.
#
# **reserved_room_type:** Code of room type reserved by the guest.
#
# **assigned_room_type:** Code for the room type actually assigned to the guest.
#
# **booking_changes**: Number of changes made to the booking.
#
# **deposit_type**: Type of deposit made (No Deposit, Refundable, Non Refundable).
#
# **agent**: ID of the travel agent who made the booking.
#
# **company**: ID of the company that made the booking (if any).
#
# **days_in_waiting_list**: Number of days the booking was on the waiting list.
#
# **customer_type**: Type of customer (Contract, Group, Transient, Transient-Party).
#
# **adr**: Average Daily Rate, defined as the total revenue divided by the number of nights.
#
# **required_car_parking_spaces**: Number of parking spaces required by the customer.
#
# **total_of_special_requests:** Total number of special requests made by the customer.
#
# **reservation_status: Reservation status** (Canceled, Check-Out, or No-Show).
#
# **reservation_status_date:** Date at which the last status change was made.

# %% [markdown]
# # ***3. Data Wrangling***

# %% [markdown]
# # Data Wrangling Code

# %%
# Data Wrangling Code
# Handling missing values
hotel_df['children'].fillna(0, inplace=True)
hotel_df.dropna(subset=['country'], inplace=True)

# Changing data types
hotel_df['reservation_status_date'] = pd.to_datetime(hotel_df['reservation_status_date'])
# Out:
# <ipython-input-16-0c58551ed697>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hotel_df['children'].fillna(0, inplace=True)

# %% [markdown]
# # What all manipulations have you done and insights you found?
#
# **1) Filled Missing Values:** For the 'children' column, missing values were filled with 0.
#
# **2) Dropped Rows with Missing Country:** Since country is important for analysis, rows with missing 'country' were removed.
#
# **3) Converted Reservation Status Date:** Transformed 'reservation_status_date' to datetime for time-based analysis.

# %% [markdown]
# # ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8, 6))
hotel_counts = hotel_df['hotel'].value_counts()
plt.bar(hotel_counts.index, hotel_counts.values, color=['skyblue', 'salmon'])
plt.title('Count of Bookings by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares categorical data, making it easy to visualize the number of bookings for each hotel type (city vs. resort). It helps identify which type is more popular among guests.

# %% [markdown]
# ####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that one type of hotel has significantly more bookings than the other. For example, if city hotels have more bookings, it indicates a preference for urban locations.

# %% [markdown]
# ####3. Will the gained insights help creating a positive business impact?
#
# **Are** there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This could lead to negative growth if the resort hotel is not optimized to attract customers. If management does not address this imbalance, the resort may suffer from reduced revenue and operational inefficiencies.

# %% [markdown]
# ####Chart-2

# %%
# Chart - 2 visualization code
avg_adr = hotel_df.groupby('arrival_date_month')['adr'].mean().reset_index()
plt.plot(avg_adr['arrival_date_month'], avg_adr['adr'], marker='o', color='purple')
plt.title('Average Daily Rate (ADR) Over Time')
plt.xlabel('Month')
plt.ylabel('Average Daily Rate')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ####1. Why did you pick the specific chart?

# %% [markdown]
#  line chart is ideal for showing trends over time.

# %% [markdown]
# ####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart may show an upward or downward trend in ADR, indicating pricing power or demand fluctuations. For instance, if ADR increases during peak tourist seasons, it reflects higher demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, by understanding guest stay patterns, hotels can optimize their offerings (e.g., packages or promotions) for the more popular hotel type. If one hotel type consistently has shorter stays, it may require targeted marketing efforts to encourage longer visits.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(x='hotel', y='stays_in_week_nights', data=hotel_df)
plt.title('Length of Stay by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Number of Week Nights Stayed')
plt.show()

# %% [markdown]
# ####1. Why did you pick the specific chart?

# %% [markdown]
# A box plot visualizes the distribution of numerical data and highlights outliers. It’s effective for comparing the length of stay between city and resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot may indicate that one type of hotel has longer stays than the other, which can suggest differing guest experiences or motivations for booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, by understanding guest stay patterns, hotels can optimize their offerings (e.g., packages or promotions) for the more popular hotel type. If one hotel type consistently has shorter stays, it may require targeted marketing efforts to encourage longer visits.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(x='is_canceled', hue='hotel', data=hotel_df)
plt.title('Cancellation Status by Hotel Type')
plt.xlabel('Cancellation Status')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot was chosen to visually represent the number of bookings that were canceled versus those that were not, differentiated by hotel type. This allows for a clear comparison of cancellation trends between city and resort hotels, providing insights into customer behavior and the effectiveness of each hotel type in managing bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, you may observe that one hotel type (e.g., city hotel) has a significantly higher number of cancellations compared to the other (e.g., resort hotel).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:** Understanding cancellation trends allows hotel management to identify areas needing improvement. For instance, if cancellations are high for the city hotel, the management can investigate the causes—such as pricing, service quality, or marketing strategies—and implement changes to enhance guest satisfaction and reduce cancellation rates.
#
# **Negative Growth:** If a significant percentage of bookings for a particular hotel type are being canceled, this could lead to negative growth. High cancellation rates can result in lost revenue and negatively impact the hotel's reputation. If guests perceive that they can easily cancel their reservations, they may hesitate to commit to bookings in the future. This emphasizes the need for effective marketing and customer relationship management to retain bookings and ensure customer loyalty.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(10, 6))
plt.hist(hotel_df['lead_time'], bins=30, color='orange', edgecolor='black')
plt.title('Lead Time Distribution')
plt.xlabel('Lead Time (Days)')
plt.ylabel('Number of Bookings')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram effectively shows the distribution of numerical data, making it easy to identify trends in lead time among bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram may reveal common lead times, indicating how far in advance guests typically book. If most bookings occur within a short lead time, it suggests a preference for last-minute travel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding lead time can help hotels plan for demand and allocate resources more efficiently. However, heavy reliance on short lead times may indicate a lack of customer loyalty, which could lead to negative growth.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='total_of_special_requests', data=hotel_df, palette='viridis')
plt.title('Number of Special Requests')
plt.xlabel('Total Special Requests')
plt.ylabel('Count of Bookings')
plt.show()
# Out:
# <ipython-input-27-c8f56c9b39c6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='total_of_special_requests', data=hotel_df, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot provides a straightforward way to visualize categorical counts, helping identify how often guests make special requests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The count plot can reveal commonality in special requests, indicating what guests prioritize. For instance, if many guests request extra bedding, hotels can ensure they have adequate supplies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding guest requests enables hotels to tailor services and improve guest satisfaction. Ignoring these insights could lead to negative experiences and ultimately affect guest retention.

# %% [markdown]
# #### Chart - 7

# %%
plt.figure(figsize=(8, 5))
cancellation_counts = hotel_df['is_canceled'].value_counts()
plt.pie(cancellation_counts, labels=['Not Canceled', 'Canceled'], startangle=90, colors=['lightgreen', 'salmon'])
plt.title('Booking Cancellation Percentage')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart effectively visualizes the proportion of bookings that are canceled versus those that are not, providing a straightforward overview of booking reliability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the cancellation percentage, which indicates how often guests follow through with their bookings. A high cancellation rate could highlight issues with customer satisfaction or market competitiveness.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the cancellation rate allows hotels to implement strategies to reduce it, potentially improving revenue and customer commitment. High cancellation rates can lead to negative growth if not addressed, as they may signify customer dissatisfaction.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(10, 6))
market_counts = hotel_df['market_segment'].value_counts()
plt.bar(market_counts.index, market_counts.values, color='cyan')
plt.title('Market Segment Distribution')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is suitable for comparing different market segments, making it easy to visualize which segments contribute most to bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart can reveal dominant market segments, providing insight into which customer bases are being effectively targeted. If one segment dominates, it may indicate a need for diversification.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes , businesses can focus more on the areas/platform and from which they get most number of bookings

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='hotel', y='adr', data=hotel_df, palette='Set1')
plt.title('Distribution of Average Daily Rate by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Average Daily Rate')
plt.grid()
plt.show()
# Out:
# <ipython-input-41-d3c34389300a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='hotel', y='adr', data=hotel_df, palette='Set1')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot combines a box plot and a density plot, providing a comprehensive view of the distribution of the average daily rate for each hotel type, including its frequency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart allows for an understanding of the pricing distribution for each hotel type, including median prices, spread, and the presence of outliers, which are essential for revenue management.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights from this plot can guide pricing strategies for each hotel type, optimizing rates based on market demand and competition. If one hotel type shows a very wide range of ADRs, it may indicate pricing inconsistencies that could deter guests.

# %% [markdown]
# #### Chart - 10 - Correlation Heatmap

# %%
# Exclude non-numeric columns
numeric_df = hotel_df.select_dtypes(include=[float, int])

# Generate the correlation matrix
plt.figure(figsize=(12, 8))
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap provides a visual representation of the relationships between various numerical features in the dataset. This is crucial for identifying which features are positively or negatively correlated, allowing for better insights into how they interact with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals which variables have strong correlations. For instance, you may find a high positive correlation between lead_time and is_canceled, indicating that longer lead times may lead to higher cancellation rates. Identifying these correlations helps in understanding the dynamics at play in hotel bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding correlations can lead to better strategic decisions. For example, if a strong negative correlation exists between number_of_special_requests and is_canceled, hotels can focus on enhancing guest experience with personalized services, potentially reducing cancellations. On the other hand, if there’s a negative correlation between adr and is_canceled, it may indicate that higher prices lead to more cancellations, prompting a review of pricing strategies.

# %%
# Select a few relevant numerical and categorical features for the pair plot
sns.pairplot(hotel_df, vars=['lead_time', 'adr', 'stays_in_week_nights', 'adults', 'children'], hue='hotel')
plt.title('Pair Plot of Selected Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot is useful for visualizing the relationships between multiple numerical variables and understanding how they correlate with one another. Additionally, by using the hue parameter, we can observe how different types of hotels (e.g., Resort Hotel vs. City Hotel) differ in terms of these variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The adr (average daily rate) and lead_time show a positive relationship, especially for resort hotels. Guests booking Resort Hotels tend to have a higher lead time, implying that they plan their vacations further in advance.
#
# stays_in_week_nights also shows a noticeable distinction between resort and city hotels, with resort hotels having longer stays during weekdays compared to city hotels, which are often chosen for shorter trips.
#
# The number of adults is relatively stable across both hotel types, while the number of children seems to vary more, especially for resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help hotel managers optimize their pricing and marketing strategies. For instance, resort hotels can focus on long-term vacation planning by offering discounts or packages for early bookings, while city hotels may cater to short-term travelers with last-minute deals.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of the hotel bookings dataset provided valuable insights into various aspects of the hotel business, customer behavior, and booking patterns. Here are some key conclusions derived from the project:
#
# # Understanding Customer Preferences:
#
# Through visualizations, it became evident that # Resort Hotels and # City Hotels have different patterns in terms of booking lead times, cancellation rates, and customer types. Resort hotels had a higher lead time, indicating that customers tend to book in advance, likely due to planned vacations.
# The count plot on # cancellation rates revealed that cancellations are significantly higher for City Hotels, suggesting that flexible booking options or policies could be adjusted to minimize cancellations.
# # Revenue Insights:
#
# The analysis of the # Average Daily Rate (ADR) showed a clear disparity between the two hotel types, with Resort Hotels generally having higher ADRs. This highlights that Resort Hotels may attract higher-paying customers and offer premium experiences.
# The correlation between variables like # lead time and # ADR suggested that earlier bookings tend to secure lower rates, a trend that could be leveraged for dynamic pricing strategies.
# # Customer Demographics:
#
# Through bar charts and count plots, we discovered differences in the number of # adults, children, and meal preferences across both types of hotels. Resort Hotels, for example, tend to accommodate more families with children, while City Hotels primarily attract business travelers or couples.
# The analysis can help tailor marketing efforts and promotional campaigns to better suit the target demographic of each hotel type.
# # Booking Behavior & Length of Stay:
#
# Customers staying for longer durations (especially in Resort Hotels) were more likely to book far in advance, while shorter stays were common in City Hotels. This highlights the potential for offering # early-bird discounts to long-term guests and higher last-minute rates to short-term visitors.
# Visualization of # weeknight stays showed that Resort Hotels have higher bookings over weekends, indicating a focus on leisure travelers, while City Hotels see more bookings during the week, appealing to business travelers.
# # Impact on Business Decisions:
#
# The insights derived from the data can have a # positive impact on business strategy. For example, introducing more competitive pricing for last-minute bookings in City Hotels, optimizing cancellation policies, and creating targeted promotions for different customer segments can help improve occupancy rates and overall revenue.
# On the flip side, high cancellation rates in City Hotels may indicate a # negative trend, suggesting that more flexible booking terms or loyalty programs are needed to retain customers and reduce booking volatility.
# # Feature Correlation:
#
# The # correlation heatmap showed moderate correlations between some variables, such as the number of children and total number of people, as well as ADR and lead time. This indicates that variables are reasonably independent, which is valuable for further predictive modeling efforts, like forecasting cancellations or revenue.
# # Final Remarks:
# This project effectively utilized # data wrangling, # visualization, and # basic statistical analysis to uncover key trends in hotel bookings. The insights can guide hotels in refining their marketing strategies, adjusting pricing, improving customer experience, and mitigating the risks of cancellations. Future work could involve implementing # machine learning models for predicting cancellations or customer segmentation, based on the findings from this analysis.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
